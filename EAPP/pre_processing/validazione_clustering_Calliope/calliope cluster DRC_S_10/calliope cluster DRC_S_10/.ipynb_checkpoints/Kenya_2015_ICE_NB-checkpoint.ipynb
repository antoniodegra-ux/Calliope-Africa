# %%
import calliope
import cal_graph as gg

# %%
try:
    calliope.set_log_level('Error')
except:
    calliope.set_log_verbosity('Error')
model = calliope.Model('model.yaml')
model.run()

# %%
model.to_csv(r'C:\Users\negar\Desktop\CIVICS-master\CIVICS_Kenya\Calliope_Kenya\4Nodes_No-Coffee-Lab\results')

# %%
amin=CG.C_Graph(model=model,ex_path=r'Graph_inputs.xlsx',unit='kW')
